# %%
import os
import pydicom
# %matplotlib inline
from pathlib import Path
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import glob

import skimage

import re
import numpy
import numpy as np

# %%
# def plot_data(data,cmaps):
#     #print('data: ' +str(data))
#     data_shape = np.array(data).shape
#     print('data_shape: ' +str(data_shape))
#     numImageTypes = data_shape[0]
#     print('numImageTypes: ' +str(numImageTypes))
#     numImageSets = data_shape[1]
#     print('numImageSets: ' +str(numImageSets))
#     print(numImageTypes,numImageSets)
#     fig = plt.figure(figsize=(3*numImageTypes,3*numImageSets))
#     for i in range(numImageSets):
#         for j in range(numImageTypes):
#             plt.subplot(numImageSets, numImageTypes,i*numImageTypes + j+1)
#             plt.axis('off')
#             img = plt.imshow(data[j][i])
#             img.set_cmap(cmaps[j])
#     plt.show()

# %% [markdown]
# ### load data

# %%
_all_files = glob.glob('../data/raw/newData/**/*mask2_*.dcm', recursive=True)
train_scan_files = [s.replace("_mask2_", "_t1_") for s in _all_files]
train_seg_files = [s.replace("_t1_", "_mask2_") for s in train_scan_files]

# discard dicom with "palque" name
#train_scan_files = [s for s in train_scan_files if not 'plaque' in s]
#train_seg_files = [s for s in train_seg_files if not 'plaque' in s]
# for s in train_seg_files:
#     if(not 'plaque' in s):
#         #print(s)
#         train_seg_files.append(s)



# test files
seg_files=train_seg_files
scan_files=train_scan_files

# %%
seg_files
#len(seg_files)
# Out:
# ['../data/raw/newData/AU128_mask2_0_RIGHT.dcm',
#  '../data/raw/newData/AU128_mask2_0_LEFT.dcm']

# %%
scan_files
#len(scan_files)
# Out:
# ['../data/raw/newData/AU128_t1_0_RIGHT.dcm',
#  '../data/raw/newData/AU128_t1_0_LEFT.dcm']

# %%
print(seg_files[0])
print('-----------------')
print(scan_files[0])
# Out:
# ../data/raw/newData/AU128_mask2_0_RIGHT.dcm
# -----------------
# ../data/raw/newData/AU128_t1_0_RIGHT.dcm

# %%
segs = []
scans = []

for s in (seg_files):
    ds = pydicom.dcmread(s)
    segs.append(ds.pixel_array)
    

for t in (scan_files):
    dt = pydicom.dcmread(t)
    scans.append(dt.pixel_array)

# %% [markdown]
# ### Plot

# %%
def plot_data(data, cmaps):
    data_shape = np.array(data).shape
    numImageTypes = data_shape[0]
    numImageSets = data_shape[1]
    fig = plt.figure(figsize=(3*numImageTypes, 3*numImageSets))
    for i in range(numImageSets):
        for j in range(numImageTypes):
            plt.subplot(numImageSets, numImageTypes, i*numImageTypes + j+1)
            plt.axis('off')
            img = plt.imshow(data[j][i])
            img.set_cmap(cmaps[j])
    plt.show()

# %%
for i, scanList in enumerate(scans):
    
    for j, scan in enumerate(scanList):  
        plt.imshow(scan, cmap='gray')
        plt.title('index: ' +str(i))
        plt.axis('off')
        plt.show()

# %%
for i, seg in enumerate(segs):
    
#     if(len(np.unique(seg)) > 2):
    print('seg Values: ' + str(np.unique(seg)))
    
    plt.imshow(seg, cmap='gnuplot')
    plt.title('index: ' +str(i))
    plt.axis('off')
    plt.show()
# Out:
# seg Values: [0 1 2]
# seg Values: [0 1 2]

# %%
#plot_data([scans, segs], ['gray', 'gnuplot'])

# %%
scans = []
for s in (scan_files):
    ds = pydicom.dcmread(s)
    scans.append(ds)
    #print(ds)
len(scans)
# Out:
# 59

# %%
# scans = [scans.append(pydicom.dcmread(s)) for s in scan_files]
# len(scans)

# %%
segs = []
for s in (seg_files):
    ds = pydicom.dcmread(s)
    segs.append(ds)
    #print(ds.PatientsName)
len(segs)
# Out:
# 59

# %%
# segs = [segs.append(pydicom.dcmread(t)) for t in seg_files]
# len(segs)

# %%
for i, scan in enumerate(scans):
    print(scan.dir("pat"))
# Out:
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientMotherBirthName', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientIdentityRemoved', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']
# ['AdditionalPatientHistory', 'ImageOrientationPatient', 'ImagePositionPatient', 'IssuerOfPatientID', 'OtherPatientNames', 'PatientAge', 'PatientBirthDate', 'PatientID', 'PatientName', 'PatientPosition', 'PatientSex', 'PatientSize', 'PatientWeight']

# %%
for i, seg in enumerate(segs):
    print(seg.dir("instance"))
# Out:
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']
# ['InstanceCreationDate', 'InstanceNumber', 'SOPInstanceUID', 'SeriesInstanceUID', 'StudyInstanceUID']

# %%
for i, scan in enumerate(scans):
    print(scan.PatientName)
# Out:
# AU128^Patient
# AU128^Patient
# AH003^Patient
# AF066^Patient
# AH003^Patient
# AL013^Patient
# AF066^Patient
# AF066^Patient
# AF066^Patient
# AU128^Patient
# AH003^Patient
# AU128^Patient
# AH003^Patient
# AH003^Patient
# AL013^Patient
# AL013^Patient
# AL013^Patient
# AU128^Patient
# AH003^Patient
# AU128^Patient
# AH003^Patient
# AF066^Patient
# AF066^Patient
# AU128^Patient
# AH003^Patient
# AH003^Patient
# AH003^Patient
# AH003^Patient
# AF066^Patient
# AU128^Patient
# AH003^Patient
# AF066^Patient
# AL013^Patient
# AH003^Patient
# AL013^Patient
# AH003^Patient
# AU128^Patient
# AF066^Patient
# AU128^Patient
# AL013^Patient
# AU128^Patient
# AU128^Patient
# AU128^Patient
# AU128^Patient
# AH003^Patient
# AH003^Patient
# AF066^Patient
# AH003^Patient
# AU128^Patient
# AU128^Patient
# AH003^Patient
# AH003^Patient
# AF066^Patient
# AF066^Patient
# AF066^Patient
# AH003^Patient
# AH003^Patient
# AF066^Patient
# AF066^Patient

# %%
for i, scan in enumerate(scans):
    print(scan)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20190227'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519676.56
# (0008, 0020) Study Date                          DA: '20190227'
# (0008, 0021) Series Date                         DA: '20190227'
# (0008, 0022) Acquisition Date                    DA: '20190227'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '153340.788000'
# (0008, 0031) Series Time                         TM: '164738.925000'
# (0008, 0032) Acquisition Time                    TM: '162042.947500'
# (0008, 0033) Content Time                        TM: '120116.353000'
# (0008, 0050) Accession Number                    SH: 'AVQIGKAPHQ'
# (0008, 0051)  Issuer of Accession Number Sequence   1 item(s) ----
#    (0040, 0031) Local Namespace Entity ID           UT: '6229UKF'
#    ---------
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T2w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'Anonymous^Person'
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.316472486414575471242645430390422896059
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.209150181715438278142582103215546189442
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.58985330144092805292918327814569195885
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AU128^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '069Y'
# (0010, 1020) Patient's Size                      DS: "1.74"
# (0010, 1030) Patient's Weight                    DS: "80"
# (0010, 21b0) Additional Patient History          LT: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0064)  De-identification Method Code Sequence   3 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_69z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "2000"
# (0018, 0081) Echo Time                           DS: "161"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194655"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "53"
# (0018, 0091) Echo Train Length                   IS: "60"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.80794571369756221193634050470503429896
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.243610839707455299198276447402271781249
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "14"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['6.25210521870072', '11.6339820323665', '12.1027469988071']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.8638654138269', '-0.3382411582576', '-0.3732686239884', '-0.1830711848998', '-0.9011672578414', '0.39291540394095']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.144118460754866896534468952477001673617
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20190227 164738.928000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2306
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: "437.975"
# (0028, 1051) Window Width                        DS: "971.425"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20190227'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519676.76
# (0008, 0020) Study Date                          DA: '20190227'
# (0008, 0021) Series Date                         DA: '20190227'
# (0008, 0022) Acquisition Date                    DA: '20190227'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '153340.788000'
# (0008, 0031) Series Time                         TM: '164738.925000'
# (0008, 0032) Acquisition Time                    TM: '162042.947500'
# (0008, 0033) Content Time                        TM: '120116.479000'
# (0008, 0050) Accession Number                    SH: 'AVQIGKAPHQ'
# (0008, 0051)  Issuer of Accession Number Sequence   1 item(s) ----
#    (0040, 0031) Local Namespace Entity ID           UT: '6229UKF'
#    ---------
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T2w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1070) Operators' Name                     PN: 'Anonymous^Person'
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.316472486414575471242645430390422896059
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.209150181715438278142582103215546189442
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.58985330144092805292918327814569195885
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AU128^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '069Y'
# (0010, 1020) Patient's Size                      DS: "1.74"
# (0010, 1030) Patient's Weight                    DS: "80"
# (0010, 21b0) Additional Patient History          LT: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0064)  De-identification Method Code Sequence   3 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['PFP', 'SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_69z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "2000"
# (0018, 0081) Echo Time                           DS: "161"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194655"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "53"
# (0018, 0091) Echo Train Length                   IS: "60"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.80794571369756221193634050470503429896
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.243610839707455299198276447402271781249
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "14"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['-39.306282506083', '12.3710399995618', '-4.2904616410748']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.68531801005891', '-0.2151118113851', '0.69574861386246', '-0.2914483123947', '-0.9565473168712', '-0.0086667057644']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.144118460754866896534468952477001673617
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20190227 164738.928000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2306
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: "437.975"
# (0028, 1051) Window Width                        DS: "971.425"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20180416'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519672.136
# (0008, 0020) Study Date                          DA: '20180410'
# (0008, 0021) Series Date                         DA: '20180416'
# (0008, 0022) Acquisition Date                    DA: '20180416'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '113728.110000'
# (0008, 0031) Series Time                         TM: '141713.175000'
# (0008, 0032) Acquisition Time                    TM: '115030.167500'
# (0008, 0033) Content Time                        TM: '120112.864000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.106633222737587722303196513252687552275
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.261588957599341526156799008944969361228
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.130991354714418072426157716687860140416
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.296193502602198407488423118412470016605
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AH003^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '075Y'
# (0010, 1020) Patient's Size                      DS: "1.75"
# (0010, 1030) Patient's Weight                    DS: "83"
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 21c0) Pregnancy Status                    US: 4
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194809"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.248040883369966890827315598164804215134
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.124196087183666256352764073591830949259
# (0020, 0010) Study ID                            SH: 'KAKJKSZBUO'
# (0020, 0011) Series Number                       IS: "17"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['-6.6959755166044', '-14.62151480217', '53.1121068379027']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.46415781772976', '-0.5273874187131', '-0.7116319489901', '-0.5918825663309', '-0.7823859924846', '0.19377096386552']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.111778571345367327632570755343486993936
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20180416 141713.181000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1248
# (0028, 1050) Window Center                       DS: "181"
# (0028, 1051) Window Width                        DS: "450"
# (0028, 1055) Window Center & Width Explanation   LO: 'WINDOW1'
# (0032, 1060) Requested Procedure Description     LO: 'MR Hals'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180416'
# (0040, 0245) Performed Procedure Step Start Time TM: '141713.175'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR13222.36744284'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hals'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20180911'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519670.16
# (0008, 0020) Study Date                          DA: '20180911'
# (0008, 0021) Series Date                         DA: '20180911'
# (0008, 0022) Acquisition Date                    DA: '20180911'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '141629.959000'
# (0008, 0031) Series Time                         TM: '164324.113000'
# (0008, 0032) Acquisition Time                    TM: '142944.937500'
# (0008, 0033) Content Time                        TM: '120110.114000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0051)  Issuer of Accession Number Sequence   1 item(s) ----
#    (0040, 0031) Local Namespace Entity ID           UT: '6229UKF'
#    ---------
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.211648531354067569408411356352233231293
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.35233380287034879080569999553166054435
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.55911019549782363994180155770869699759
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.185888578310376006654347582866685326219
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AF066^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '055Y'
# (0010, 1020) Patient's Size                      DS: "1.63"
# (0010, 1030) Patient's Weight                    DS: "62"
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194551"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.189026576320616638169808747368714153187
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.170261582005839983694785358236812456713
# (0020, 0010) Study ID                            SH: 'PKSEVKFBFJ'
# (0020, 0011) Series Number                       IS: "13"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['68.722061267211', '-44.959056528203', '31.2318476717376']
# (0020, 0037) Image Orientation (Patient)         DS: ['-0.9476262559931', '0.09893850089987', '0.30367030146564', '0.18332573587442', '0.94707484553936', '0.26351643499542']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.187529645162737653840657988688045877769
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20180911 164324.117000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 752
# (0028, 1050) Window Center                       DS: "318.3875"
# (0028, 1051) Window Width                        DS: "682.1375"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 1060) Requested Procedure Description     LO: 'MR Hals'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180911'
# (0040, 0245) Performed Procedure Step Start Time TM: '141729.881'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR35826.37781816'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hals'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20180416'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519672.104
# (0008, 0020) Study Date                          DA: '20180410'
# (0008, 0021) Series Date                         DA: '20180416'
# (0008, 0022) Acquisition Date                    DA: '20180416'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '113728.110000'
# (0008, 0031) Series Time                         TM: '141713.175000'
# (0008, 0032) Acquisition Time                    TM: '115030.167500'
# (0008, 0033) Content Time                        TM: '120112.664000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.106633222737587722303196513252687552275
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.261588957599341526156799008944969361228
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.130991354714418072426157716687860140416
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.296193502602198407488423118412470016605
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AH003^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '075Y'
# (0010, 1020) Patient's Size                      DS: "1.75"
# (0010, 1030) Patient's Weight                    DS: "83"
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 21c0) Pregnancy Status                    US: 4
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194809"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.248040883369966890827315598164804215134
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.124196087183666256352764073591830949259
# (0020, 0010) Study ID                            SH: 'KAKJKSZBUO'
# (0020, 0011) Series Number                       IS: "17"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['59.674965368459', '-56.928718180101', '15.9374224910804']
# (0020, 0037) Image Orientation (Patient)         DS: ['-0.7878068739923', '0.11530556567824', '0.60503302043283', '0.10726520299136', '0.99299379161697', '-0.0495732391253']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.111778571345367327632570755343486993936
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20180416 141713.181000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1248
# (0028, 1050) Window Center                       DS: "181"
# (0028, 1051) Window Width                        DS: "450"
# (0028, 1055) Window Center & Width Explanation   LO: 'WINDOW1'
# (0032, 1060) Requested Procedure Description     LO: 'MR Hals'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180416'
# (0040, 0245) Performed Procedure Step Start Time TM: '141713.175'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR13222.36744284'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hals'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20180511'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519674.112
# (0008, 0020) Study Date                          DA: '20180511'
# (0008, 0021) Series Date                         DA: '20180511'
# (0008, 0022) Acquisition Date                    DA: '20180511'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '111134.542000'
# (0008, 0031) Series Time                         TM: '123015.908000'
# (0008, 0032) Acquisition Time                    TM: '120659.172500'
# (0008, 0033) Content Time                        TM: '120114.721000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.296960107864608411372977874474441514
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.309175574268684172180915513781535315173
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.222392299727829223245440482197695879240
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.24538328277738824333440091717799060566
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AL013^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '068Y'
# (0010, 1020) Patient's Size                      DS: "1.74"
# (0010, 1030) Patient's Weight                    DS: "77"
# (0010, 1060) Patient's Mother's Birth Name       PN: ''
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.19475"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.258417377776250815515246585153625142004
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.303738191651732817178339067782660836921
# (0020, 0010) Study ID                            SH: 'QUTTVCFOCJ'
# (0020, 0011) Series Number                       IS: "20"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['-50.466669982659', '-18.383576101382', '39.0989175256812']
# (0020, 0037) Image Orientation (Patient)         DS: ['0.78649695291159', '-0.3269083767941', '-0.5239784883396', '-0.4797135679503', '-0.8577156593456', '-0.1849290145913']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.328434620832588926464467005970110755948
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# ...
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '141629.959000'
# (0008, 0031) Series Time                         TM: '164324.113000'
# (0008, 0032) Acquisition Time                    TM: '142944.937500'
# (0008, 0033) Content Time                        TM: '120110.065000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0051)  Issuer of Accession Number Sequence   1 item(s) ----
#    (0040, 0031) Local Namespace Entity ID           UT: '6229UKF'
#    ---------
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.211648531354067569408411356352233231293
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.35233380287034879080569999553166054435
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.55911019549782363994180155770869699759
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.185888578310376006654347582866685326219
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AF066^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '055Y'
# (0010, 1020) Patient's Size                      DS: "1.63"
# (0010, 1030) Patient's Weight                    DS: "62"
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194551"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.189026576320616638169808747368714153187
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.170261582005839983694785358236812456713
# (0020, 0010) Study ID                            SH: 'PKSEVKFBFJ'
# (0020, 0011) Series Number                       IS: "13"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['58.5332566047967', '-48.201018127364', '34.8732750245195']
# (0020, 0037) Image Orientation (Patient)         DS: ['-0.5630727411887', '-0.0357229620013', '0.82563488184309', '0.04210247947335', '0.99652785941263', '0.07183040189693']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.187529645162737653840657988688045877769
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20180911 164324.117000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 752
# (0028, 1050) Window Center                       DS: "318.3875"
# (0028, 1051) Window Width                        DS: "682.1375"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 1060) Requested Procedure Description     LO: 'MR Hals'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180911'
# (0040, 0245) Performed Procedure Step Start Time TM: '141729.881'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR35826.37781816'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hals'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'OTHER', 'MEVISLAB']
# (0008, 0012) Instance Creation Date              DA: '20180911'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.34261.26601942345532.3012.1572519669.144
# (0008, 0020) Study Date                          DA: '20180911'
# (0008, 0021) Series Date                         DA: '20180911'
# (0008, 0022) Acquisition Date                    DA: '20180911'
# (0008, 0023) Content Date                        DA: '20191031'
# (0008, 0030) Study Time                          TM: '141629.959000'
# (0008, 0031) Series Time                         TM: '164324.113000'
# (0008, 0032) Acquisition Time                    TM: '142944.937500'
# (0008, 0033) Content Time                        TM: '120109.966000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0051)  Issuer of Accession Number Sequence   1 item(s) ----
#    (0040, 0031) Local Namespace Entity ID           UT: '6229UKF'
#    ---------
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'Cardio_MRI_Studies^vascular_neu^Carotids_Multi-Contrast2'
# (0008, 1032)  Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0008, 103e) Series Description                  LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff_RR'
# (0008, 1050) Performing Physician's Name         PN: ''
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Prisma_fit'
# (0008, 1111)  Referenced Performed Procedure Step Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.211648531354067569408411356352233231293
#    ---------
# (0008, 1140)  Referenced Image Sequence   3 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.35233380287034879080569999553166054435
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.55911019549782363994180155770869699759
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: MR Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.185888578310376006654347582866685326219
#    ---------
# (0010, 0010) Patient's Name                      PN: 'AF066^Patient'
# (0010, 0020) Patient ID                          LO: ''
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1010) Patient's Age                       AS: '055Y'
# (0010, 1020) Patient's Size                      DS: "1.63"
# (0010, 1030) Patient's Weight                    DS: "62"
# (0010, 21b0) Additional Patient History          LT: ''
# (0010, 2299) Responsible Organization            LO: 'X'
# (0018, 0015) Body Part Examined                  CS: 'CAROTID'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: ['SK', 'SP', 'OSP']
# (0018, 0022) Scan Options                        CS: ['SAT2', 'FS']
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: 'spc_36z'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "0.60000002384186"
# (0018, 0080) Repetition Time                     DS: "900"
# (0018, 0081) Echo Time                           DS: "30"
# (0018, 0083) Number of Averages                  DS: "2"
# (0018, 0084) Imaging Frequency                   DS: "123.194551"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "1"
# (0018, 0087) Magnetic Field Strength             DS: "3"
# (0018, 0088) Spacing Between Slices              DS: "0.17578125"
# (0018, 0089) Number of Phase Encoding Steps      IS: "66"
# (0018, 0091) Echo Train Length                   IS: "36"
# (0018, 0093) Percent Sampling                    DS: "100"
# (0018, 0094) Percent Phase Field of View         DS: "25"
# (0018, 0095) Pixel Bandwidth                     DS: "405"
# (0018, 1020) Software Version(s)                 LO: 'syngo MR E11'
# (0018, 1030) Protocol Name                       LO: 'T1w_tse_vfl_Zoom_slicePF_PAToff'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1310) Acquisition Matrix                  US: [256, 0, 0, 64]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'COL'
# (0018, 1314) Flip Angle                          DS: "120"
# (0018, 1315) Variable Flip Angle Flag            CS: 'Y'
# (0018, 1316) SAR                                 DS: "0"
# (0018, 1318) dB/dt                               DS: "0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 1.2.40.0.13.1.189026576320616638169808747368714153187
# (0020, 000e) Series Instance UID                 UI: 1.2.40.0.13.1.170261582005839983694785358236812456713
# (0020, 0010) Study ID                            SH: 'PKSEVKFBFJ'
# (0020, 0011) Series Number                       IS: "13"
# (0020, 0012) Acquisition Number                  IS: "2"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['55.2639478849057', '-46.914557870109', '35.0757853916796']
# (0020, 0037) Image Orientation (Patient)         DS: ['-0.8557894482203', '0.32153880985334', '-0.4052619079964', '0.1268386921877', '0.88988431249608', '0.43819842142287']
# (0020, 0052) Frame of Reference UID              UI: 1.2.40.0.13.1.187529645162737653840657988688045877769
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: 'MeVisLab'
# (0021, 0010) Private Creator                     LO: 'MeVis eD: Timepoint Information'
# (0021, 1010) Private tag data                    LT: '20180911 164324.117000'
# (0021, 1011) Private tag data                    CS: 'UNKNOWN'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "1"
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: ['0.17578125', '0.17578125']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 752
# (0028, 1050) Window Center                       DS: "318.3875"
# (0028, 1051) Window Width                        DS: "682.1375"
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 1060) Requested Procedure Description     LO: 'MR Hals'
# (0032, 1064)  Requested Procedure Code Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: '6032'
#    (0008, 0102) Coding Scheme Designator            SH: '99GAP'
#    (0008, 0104) Code Meaning                        LO: 'MR Hals'
#    ---------
# (0040, 0244) Performed Procedure Step Start Date DA: '20180911'
# (0040, 0245) Performed Procedure Step Start Time TM: '141729.881'
# (0040, 0253) Performed Procedure Step ID         SH: 'MR35826.37781816'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'MR Hals'
# (0040, 0280) Comments on the Performed Procedure ST: ''
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 bytes

# %%
# patients = {}
# for i, (scan,seg) in enumerate(zip(scans, seg)):
#     if (scan.PatientName not in patients):
#         #pat_folder_regex = re.compile(r'Pat\w\d{2}\w{2}\d{3}\w{2}\d')
#         pat_folder_regex = re.compile(r'w{2}d{3}\w{1}Patient')
#         print( pat_folder_regex)
#         print(" SCAN I" +str(scan_files[i]))
#         patient_folder = re.search(pat_folder_regex, scan_files[i], flag=0)
#         seg_file = segs['%s.nrrd' % patient_folder]

# %%
pseudo =[]
for i, scan in enumerate(scans):
    patientName = str(scan.PatientName)
    patientName_list = patientName.split('^')
    print(patientName)
    print(patientName_list)
    print(patientName_list[0])
    
    # Extract filepath and filename
    filepath, filename = os.path.split(scan_files[i])   
    patientName2 = filename.split('_')[0]
    
    print(patientName2)
    
    if patientName_list[0] == patientName2:
        print("zero:"+str(0))
# Out:
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AL013^Patient
# ['AL013', 'Patient']
# AL013
# AL013
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AU128^Patient
# ['AU128', 'Patient']
# AU128
# AU128
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AH003^Patient
# ['AH003', 'Patient']
# AH003
# AH003
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
# AF066^Patient
# ['AF066', 'Patient']
# AF066
# AF066
# zero:0
